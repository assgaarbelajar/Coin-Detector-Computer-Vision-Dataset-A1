# %%
# Kloning repository YOLOv5
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Instalasi dependencies yang diperlukan
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17639, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 17639 (delta 16), reused 11 (delta 7), pack-reused 17589 (from 2)
# Receiving objects: 100% (17639/17639), 17.03 MiB | 17.32 MiB/s, done.
# Resolving deltas: 100% (11990/11990), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
# Ini akan meminta Anda untuk otorisasi dan memasukkan kode verifikasi
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-3975240732.py in <cell line: 0>()
#       1 from google.colab import drive
#       2 # Ini akan meminta Anda untuk otorisasi dan memasukkan kode verifikasi
# ----> 3 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
# ...

# %%
# Ganti 'YOLO_Koin' dengan nama folder yang Anda gunakan di Drive
data_yaml_path = '/content/gdrive/MyDrive/yolo_coin_detector/data.yaml'

# !python train.py --img 640 --batch 16 --epochs 50 --data {data_yaml_path} --weights yolov5s.pt --name coin_detector
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-10-26 10:43:10.990578: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761475391.057121    2908 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761475391.081917    2908 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761475391.144855    2908 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls /content/runs/train/coin_detector3/weights
# !ls /content/gdrive/MyDrive/yolo_coin_detector/runs/train/coin_detector3/weights
# Out:
# ls: cannot access '/content/runs/train/coin_detector3/weights': No such file or directory
# ls: cannot access '/content/gdrive/MyDrive/yolo_coin_detector/runs/train/coin_detector3/weights': No such file or directory

# %%
# 1. PINDAH KE FOLDER YOLOv5
# %cd /content/yolov5

weights_path_local = '/content/gdrive/MyDrive/yolo_coin_detector/runs/train/coin_detector3/weights/best.pt'


video_source_path = '/content/gdrive/MyDrive/yolo_coin_detector/inference_video/koinkoin.mp4'

# !python detect.py \
    --source {video_source_path} \
    --weights {weights_path_local} \
    --project /content/gdrive/MyDrive/YOLO_Koin/YOLO_output \
    --name Final_Detection_Video \
    --exist-ok
# Out:
# /content/yolov5
# detect: weights=['/content/gdrive/MyDrive/yolo_coin_detector/runs/train/coin_detector3/weights/best.pt'], source=/content/gdrive/MyDrive/yolo_coin_detector/inference_video/koinkoin.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/gdrive/MyDrive/YOLO_Koin/YOLO_output, name=Final_Detection_Video, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-443-gbe00b6b6 Python-3.12.12 torch-2.8.0+cu126 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov5/detect.py", line 438, in <module>
#     main(opt)
#   File "/content/yolov5/detect.py", line 433, in main
#     run(**vars(opt))
# ...
